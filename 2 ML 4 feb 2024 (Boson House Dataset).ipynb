# %%
# !pip install scikit-learn

# %%
import numpy as np
import matplotlib as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline
import warnings
warnings.simplefilter("ignore")
from sklearn.datasets import load_boaston
from sklearn.metrices import  train_test_spilt
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import Gridseachy
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet

# %%
df = pd.read_csv("C:\\Users\\Rahul\\Downloads\\archive(1)\\boston.csv")
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
column_name = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
boston_data = pd.read_csv("C:\\Users\\Rahul\\Downloads\\archive(1)\\boston.csv")
boston_data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
boston_data.shape
# Out:
# (506, 14)

# %%
boston_data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
boston_data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
sns.histplot(boston_data)


boston_data = pd.DataFrame(boston.data)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(boston_data['MEDV'],bins=30)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 3
#       1 sns.set(rc={'figure.figsize':(11.7,8.27)})
#       2 sns.distplot(boston_data['MEDV'],bins=30)
# ----> 3 plt.show()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\_api\__init__.py:217, in caching_module_getattr.<locals>.__getattr__(name)
#     215 if name in props:
#     216     return props[name].__get__(instance)
# --> 217 raise AttributeError(
#     218     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(boston_data['CRIM'],bins=30)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 3
#       1 sns.set(rc={'figure.figsize':(11.7,8.27)})
#       2 sns.distplot(boston_data['CRIM'],bins=30)
# ----> 3 plt.show()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\_api\__init__.py:217, in caching_module_getattr.<locals>.__getattr__(name)
#     215 if name in props:
#     216     return props[name].__get__(instance)
# --> 217 raise AttributeError(
#     218     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(boston_data['ZN'],bins=30)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 3
#       1 sns.set(rc={'figure.figsize':(11.7,8.27)})
#       2 sns.distplot(boston_data['ZN'],bins=30)
# ----> 3 plt.show()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\_api\__init__.py:217, in caching_module_getattr.<locals>.__getattr__(name)
#     215 if name in props:
#     216     return props[name].__get__(instance)
# --> 217 raise AttributeError(
#     218     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
ridge = Ridge()
params = {"alpha":[1e-15,1e-10,1e-8,1e-2,1,5,10]}

ridge_model = GridSearchCV(ridge,params,scoring = "neg_mean_squared_error",cv = 10)
# Out:
#   Cell In[35], line 4
#     ridge_model = GridSearchCV(ridge,params,scoring = "neg_mean_squared_error",cv = 10)
#                                                                                  ^
# SyntaxError: invalid non-printable character U+00A0

# %%
cvs= cross_cross_val_score(lin_model,x,y,scoring="neg_mean_squared_error", cv=10)
print(cvs)
mean_cvs=np.mean(cvs)
print(mean_cvs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 cvs= cross_cross_val_score(lin_model,x,y,scoring="neg_mean_squared_error", cv=10)
#       2 print(cvs)
#       3 mean_cvs=np.mean(cvs)
#
# NameError: name 'cross_cross_val_score' is not defined

# %%
lin_model = linearRegression()
lin_model.fix(x_train,y_train)
lin_model.predict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 lin_model = linearRegression()
#       2 lin_model.fix(x_train,y_train)
#       3 print(lin_model)
#
# NameError: name 'linearRegression' is not defined
