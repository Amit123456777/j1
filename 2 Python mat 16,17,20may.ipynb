# %%
# kde = kernal density estimation

# %%
# histogramm tells the frequency. for ex how man data bet 0 to 3

# %%
import matplotlib.pyplot as plt
import numpy as np
a = np.random.randn(100)
plt.plot(a)

# %%
# distribution plot - fro density
# histplot  - for frequency
# HIST HAS NO Y AXIS

# %%
b = np.random.randn(1000)
plt.hist(b)
# Out:
# (array([  8.,  17.,  75., 144., 206., 249., 158.,  98.,  32.,  13.]),
#  array([-3.08215258, -2.48675686, -1.89136113, -1.29596541, -0.70056968,
#         -0.10517396,  0.49022177,  1.08561749,  1.68101322,  2.27640894,
#          2.87180466]),
#  <BarContainer object of 10 artists>)

# %%
b = np.random.randn(1000)
plt.distribution(b)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 b = np.random.randn(1000)
# ----> 2 plt.distribution(b)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'distribution'

# %%
# BAR PLOT IS USED TO COMPARE 2

# arr = np.array(

# %% [markdown]
# # pie chart

# %%
# auto pct for percentage
# is ok for 5, 7 featuress only

# %% [markdown]
# # 17 may 2024

# %% [markdown]
# # line chart

# %%
# it tells the trend

# %%
# Create a matrix
import numpy as np
import matplotlib.pyplot as plt

matrix1 = np.random.rand(10, 20)

cp = plt.contour(matrix1)

plt.show()

# %%
matrix = np.random.randn(10, 20)
csr = plt.contourf(matrix)
plt.colorbar()
plt.show()

# %%
x15 = np.arange(1, 5)

plt.plot(x15, x15*1.5, x15, x15*3.0, x15, x15/3.0)

plt.grid()

plt.show()

# %%
x = [2,3,4,5,6]
plt.plot(x)

# %%
# below plots are used for mulitvariant analysis
# heat map is used for multivariabt analusis
# pair plot also

# %%
import seaborn as sns
current_palette1 = sns.color_palette()

sns.palplot(current_palette1)

plt.show()

# %%
tips = sns.load_dataset('tips')

# %%
# # skewness picture 
# normal
# -ve
# +ve
# see image on google

# %%
# types of distribution

# normal = for numeric
# binomial for categorical

# note : distribution plot is always for numeric data

# %%
# histogram tells the frequency

# %%
# kde kernal density estimate

# %% [markdown]
# # 20 may 2024

# %%
# bivariant - histogram or scatter plot., joint plot

# %%
# three types of relation
# +ve = upward slope
# -ve = downward slop
# neutral = all the points are randomlu scattered, no relation

# %%
sns.set_style("ticks")

sns.pairplot(tips)

plt.show()

# %%
import seaborn as sns
tips = sns.load_dataset('tips')
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['size']
# Out:
# 0      2
# 1      3
# 2      3
# 3      2
# 4      4
#       ..
# 239    3
# 240    2
# 241    2
# 242    2
# 243    2
# Name: size, Length: 244, dtype: int64

# %%
sns.set_style("ticks")

sns.pairplot(tips)

plt.show()

# %%
sns.scatterplot(x="total_bill", y="size", data=tips)

plt.show()

# %% [markdown]
# # strip plot

# %%
sns.stripplot(x = "day", y = "total_bill", data = tips)
plt.show()

# %%
sns.stripplot(x = "day", y = "total_bill", data = tips, jitter = True)
plt.show()

# %%
sns.boxplot(tips["total_bill"])
plt.show()

# %%
sns.violinplot(x= tips["total_bill"])
plt.show()

# %% [markdown]
# # bar plot

# %%
# A barplot shows the relation between a categorical 
# variable and a continuous variable. The data is 
# represented in rectangular bars where the length the bar represents 
# the proportion of the data in that category.

# %%
# 27 Reg Plot

# %%
# It is a trend plotting line.
# It is very important

# %%
# also serch from LM plot

# %%
sns.lmplot(x = "total_bill", y = "tip", data = tips)
plt.show()
