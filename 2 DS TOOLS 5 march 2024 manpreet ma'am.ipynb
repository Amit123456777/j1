# %%
import pandas as pd
df = pd.DataFrame({"name" : ["rohit", "raj", "shreya", "nikki", "sid"],
                   "age" : [18, 20,21,17,16],
                   "gender" : ["male", "male", "female", "female", "male"],
                   "math" : [80,90,93,97,99],
                   "science" : [80,90,78,67,60]
                  })
df
# Out:
#      name  age  gender  math  science
# 0   rohit   18    male    80       80
# 1     raj   20    male    90       90
# 2  shreya   21  female    93       78
# 3   nikki   17  female    97       67
# 4     sid   16    male    99       60

# %%
# questn 1
df.sort_values('age',axis=0,ascending=True,inplace=True,na_position='first')
df
# Out:
#      name  age  gender  math  science
# 4     sid   16    male    99       60
# 3   nikki   17  female    97       67
# 0   rohit   18    male    80       80
# 1     raj   20    male    90       90
# 2  shreya   21  female    93       78

# %%
# questn 2

df.sort_values('math',axis=0,ascending=False,inplace=True,na_position='first')
df
# Out:
#      name  age  gender  math  science
# 4     sid   16    male    99       60
# 3   nikki   17  female    97       67
# 2  shreya   21  female    93       78
# 1     raj   20    male    90       90
# 0   rohit   18    male    80       80

# %%
# questn 3

# %%
# questn 4

df.sort_values('name',axis=0,ascending=True,inplace=True,na_position='first')
df
# Out:
#      name  age  gender  math  science
# 3   nikki   17  female    97       67
# 1     raj   20    male    90       90
# 0   rohit   18    male    80       80
# 2  shreya   21  female    93       78
# 4     sid   16    male    99       60

# %%
df = df.drop(4, axis=0) # axis = 0 is default
df
# Out:
#      name  age  gender  math  science
# 3   nikki   17  female    97       67
# 1     raj   20    male    90       90
# 0   rohit   18    male    80       80
# 2  shreya   21  female    93       78

# %%
# df1.drop(0) also use (o means row index)

# %%
# ques3 shift

data = df.sort_index(axis=1, ascending = False, inplace = True)
data

# %%
import pandas as pd
df = pd.DataFrame({"name" : ["rohit", "raj", "shreya", "nikki", "sid"],
                   "age" : [18, 20,21,17,16],
                   "gender" : ["male", "male", "female", "female", "male"],
                   "marks1" : [80,90,93,97,99],
                   "marks2" : [80,90,78,67,60]
                  })
df
# Out:
#      name  age  gender  marks1  marks2
# 0   rohit   18    male      80      80
# 1     raj   20    male      90      90
# 2  shreya   21  female      93      78
# 3   nikki   17  female      97      67
# 4     sid   16    male      99      60

# %%
df.sort_index(axis=1, ascending = False, inplace = True)
df
# Out:
#      name  marks2  marks1  gender  age
# 0   rohit      80      80    male   18
# 1     raj      90      90    male   20
# 2  shreya      78      93  female   21
# 3   nikki      67      97  female   17
# 4     sid      60      99    male   16

# %%
nc = df.columns.tolist()
nc
# Out:
# ['name', 'marks2', 'marks1', 'gender', 'age']

# %%
nc.remove('gender')

# %%
nc.append("gender")
print(nc)
# Out:
# ['name', 'marks2', 'marks1', 'age', 'gender']

# %%
df_new = df[nc]
df_new
# Out:
#      name  marks2  marks1  age  gender
# 0   rohit      80      80   18    male
# 1     raj      90      90   20    male
# 2  shreya      78      93   21  female
# 3   nikki      67      97   17  female
# 4     sid      60      99   16    male

# %%
import pandas as pd
df1 = pd.DataFrame({"name" : ["tina", "ram", "shayam", "meena", "mohan"],
                   "age" : [18, 20,21,17,16],
                   "gender" : ["male", "male", "female", "female", "male"],
                   "math" : [80,90,93,97,99],
                   "science" : [80,90,78,67,60]
                  })
df1
# Out:
#      name  age  gender  math  science
# 0    tina   18    male    80       80
# 1     ram   20    male    90       90
# 2  shayam   21  female    93       78
# 3   meena   17  female    97       67
# 4   mohan   16    male    99       60

# %%
df1 = drop(1, axis= 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 df1 = drop(1, axis= 1)
#
# NameError: name 'drop' is not defined

# %%
# note: column name - colum index hota hai
